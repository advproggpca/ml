# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.scatter(10, 20, color='red', label='Point (10, 20)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()
